# %%
import pandas as pd

# %%
facility_data = pd.read_csv("../RecordFuse/data/synthetic_facility_v3.csv")
household_data = pd.read_csv("../RecordFuse/data/synthetic_hdss_v3.csv")

# %%
facility_data.head(50)
# Out:
#     recnr     firstname    lastname    petname               dob  sex  \
# 0       2        Fatuma         NaN      Zaina  24-08-2017 00:00    2
# 1       3        Gloria     Rashida        NaN  11-07-1993 00:00    2
# 2       4           Ali      Hakram      Igomu  17-05-2014 00:00    1
# 3       5      Nakalema         NaN    Nkwanga  27-02-2026 00:00    2
# 4       6        Asuman       Sempa      Aguti  02-03-2002 00:00    1
# 5       7         Haifa       Alice       Xama  27-12-1945 00:00    2
# 6       8     Namutamba      Sumaya       Bria  18-02-1997 00:00    2
# 7       9        Madina     Shirati       Sira  10-07-1997 00:00    2
# 8      10       Mulondo      Kaziba       Anko  11-11-1976 00:00    1
# 9      11        Bakali   Kisambira   Nalubega  23-12-1946 00:00    1
# 10     12        Nasiri     Kirunda      Ebitu  02-06-1959 00:00    1
# 11     13         Azena       Naula     Babiri  01-11-1976 00:00    2
# ...

# %%
facility_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2902 entries, 0 to 2901
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   recnr       2902 non-null   int64
#  1   firstname   2902 non-null   object
#  2   lastname    2835 non-null   object
#  3   petname     2511 non-null   object
#  4   dob         2902 non-null   object
#  5   sex         2902 non-null   int64
#  6   nationalid  2902 non-null   object
#  7   patientid   2902 non-null   int64
#  8   visitdate   2902 non-null   object
# dtypes: int64(3), object(6)
# memory usage: 204.2+ KB

# %%
facility_data.isnull().sum()
# Out:
# recnr           0
# firstname       0
# lastname       67
# petname       391
# dob             0
# sex             0
# nationalid      0
# patientid       0
# visitdate       0
# dtype: int64

# %%
facility_data.firstname.value_counts().head(50)
# Out:
# Nabirye      54
# Mutesi       52
# Naigaga      45
# Nakaziba     33
# Nangobi      31
# Mariam       29
# Babirye      24
# Kagoya       23
# Fatuma       22
# Nakagolo     22
# Namukose     20
# Sarah        18
# Madina       18
# Namuwaya     16
# Namususwa    16
# Florence     16
# Kisambira    16
# Hadija       15
# Kaziba       15
# Namaganda    14
# Sauya        13
# Salima       13
# Muwaya       13
# Naiwumbwe    13
# Shanita      13
# Nankwanga    13
# Zabina       13
# Tenywa       12
# John         12
# Sumaya       12
# Betty        12
# Janet        11
# Nakidodo     11
# Ruth         11
# Fahadi       11
# Mwesigwa     11
# Amina        10
# Hassan       10
# Zaina        10
# Namusobya    10
# Christine    10
# Nakasolo      9
# Anisha        9
# Jamira        9
# Faizo         9
# Damali        9
# Rose          9
# Kauma         9
# Hajara        9
# Bushira       9
# Name: firstname, dtype: int64

# %%
print(facility_data.lastname.value_counts().head(50))
# Out:
# Naigaga       55
# Nabirye       48
# Mutesi        46
# Nangobi       40
# Nakaziba      39
# Nakagolo      33
# Namaganda     29
# Babirye       29
# Shanita       18
# Sumaya        17
# Nankwanga     17
# Kagoya        16
# Fatuma        16
# Kauma         15
# Shakira       14
# Nakiranda     14
# Mariam        14
# Kisambira     14
# Naiwumbwe     14
# Isabirye      13
# Aisha         13
# Waiswa        12
# Namukose      12
# Namulondo     12
# Nakanda       12
# Lydia         11
# Sarah         11
# Kakaire       11
# Nakisuyi      11
# Sowobi        11
# Namuwaya      10
# Namusubo      10
# Lwabaga       10
# Namwebya      10
# Shaluwa        9
# Kigenyi        9
# Shamira        9
# Kaudha         9
# Mutale         9
# Waigangala     9
# Namukobe       9
# Tenywa         8
# Wotali         8
# Nakadama       8
# Phiona         8
# Kirabira       8
# Namususwa      8
# Margret        8
# Namatende      8
# Janat          8
# Name: lastname, dtype: int64

# %%
print(facility_data.petname.value_counts().head(50))
# Out:
# Nakalanzi    59
# Nakato       55
# Nalubega     42
# Nabbosa      38
# Nsereko      20
# Nambi        17
# Kizito       16
# Nakyobe      15
# Nalukenge    14
# Nsibambi     13
# Namuddu      13
# Sira         13
# Nakayiza     12
# Dara         12
# Malaika      12
# Namara       11
# Kiganda      11
# Nadduli      10
# Ema          10
# Lukwago      10
# Kagimu       10
# Bintu        10
# Ekwamu       10
# Kazi         10
# Kafeero      10
# Kato          9
# Nakalema      9
# Kamya         9
# Mwesigwa      9
# Mugasha       9
# Wazi          9
# Mugabi        9
# Kirabo        9
# Nabirye       8
# Biyinzika     8
# Nalukwago     8
# Mirembe       8
# Angoma        8
# Kyakonye      8
# Tara          8
# Awori         8
# Jajja         8
# Nira          8
# Alinda        8
# Nola          7
# Panda         7
# Ayugi         7
# Bino          7
# Nalubowa      7
# Biyago        7
# Name: petname, dtype: int64

# %%
print(facility_data.dob.value_counts().head(50))
# Out:
# 26-09-1969 00:00    4
# 10-01-1933 00:00    4
# 07-11-1956 00:00    4
# 27-12-2018 00:00    4
# 08-02-2025 00:00    3
# 27-10-1959 00:00    3
# 29-05-1983 00:00    3
# 05-11-1953 00:00    3
# 10-07-1982 00:00    3
# 02-12-1989 00:00    3
# 20-12-1937 00:00    3
# 29-05-1974 00:00    3
# 21-01-1954 00:00    3
# 22-11-1991 00:00    3
# 05-04-1977 00:00    3
# 24-05-1969 00:00    3
# 08-07-1947 00:00    3
# 15-03-1962 00:00    3
# 18-02-1938 00:00    3
# 10-11-1949 00:00    3
# 05-03-1939 00:00    3
# 29-06-1947 00:00    3
# 11-11-2018 00:00    3
# 10-06-1996 00:00    3
# 10-05-1973 00:00    3
# 05-04-2024 00:00    3
# 22-03-2005 00:00    3
# 27-02-1934 00:00    3
# 06-06-1966 00:00    3
# 11-07-1972 00:00    3
# 23-01-2003 00:00    3
# 29-01-1973 00:00    3
# 23-08-1990 00:00    3
# 26-10-1933 00:00    3
# 17-07-2018 00:00    3
# 25-04-2012 00:00    2
# 16-03-1936 00:00    2
# 26-11-2024 00:00    2
# 06-11-1970 00:00    2
# 26-03-1934 00:00    2
# 04-12-1980 00:00    2
# ...

# %%
print(facility_data['nationalid'].nunique())
# Out:
# 2902

# %%
print(facility_data['patientid'].nunique())
# Out:
# 2902

# %%
print(facility_data.visitdate.value_counts().head(50))
# Out:
# 23-05-2020    7
# 27-07-2023    7
# 02-02-2019    6
# 09-01-2019    6
# 02-05-2022    6
# 11-02-2021    6
# 13-11-2022    6
# 13-08-2019    6
# 28-06-2021    6
# 16-12-2019    6
# 04-02-2021    6
# 08-10-2021    5
# 13-05-2019    5
# 29-12-2022    5
# 27-02-2019    5
# 27-08-2018    5
# 14-09-2020    5
# 19-12-2019    5
# 27-12-2022    5
# 26-10-2018    5
# 30-08-2019    5
# 23-07-2022    5
# 30-03-2021    5
# 08-02-2021    5
# 09-03-2020    5
# 16-03-2019    5
# 21-06-2022    5
# 01-10-2020    5
# 07-11-2021    5
# 30-09-2022    5
# 24-08-2020    4
# 15-07-2023    4
# 06-08-2021    4
# 26-12-2021    4
# 23-08-2022    4
# 28-11-2019    4
# 31-07-2019    4
# 03-01-2022    4
# 26-05-2022    4
# 21-08-2020    4
# 09-04-2020    4
# 21-12-2022    4
# 01-06-2019    4
# 25-07-2022    4
# 28-08-2020    4
# 27-01-2022    4
# 12-05-2019    4
# 23-11-2019    4
# 19-11-2021    4
# 10-06-2019    4
# Name: visitdate, dtype: int64

# %%
household_data.head(50)
# Out:
#     recnr   firstname   lastname   petname               dob  sex  nationalid  \
# 0       1       Zaina     Hanifa       Ula  22-09-1930 00:00    2         NaN
# 1       2     Godfrey    Maganda    Mukama  15-07-1934 00:00    1         NaN
# 2       3       Kasim      Ngobi  Galabuzi  03-03-1983 00:00    1         NaN
# 3       4      Esther        NaN     Inara  30-07-1968 00:00    2         NaN
# 4       5      Sumaya    Swabula       NaN  13-12-1930 00:00    2         NaN
# 5       6     Hussein   Nakiruba   Mukembo  25-09-1983 00:00    1         NaN
# 6       7      Mawazi       Musa   Mugasha  27-11-1975 00:00    1         NaN
# 7       8      Hassan     Kapisi   Ganyana  25-03-1981 00:00    1         NaN
# 8       9     Zubairi       Adam    Lubega  01-10-1931 00:00    1         NaN
# 9      10      Zubeda     Winnie      Isha  16-04-1935 00:00    2         NaN
# 10     11  Babigumira      Sarah      Vara  27-08-1994 00:00    2         NaN
# ...

# %%
household_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4115 entries, 0 to 4114
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   recnr       4115 non-null   int64
#  1   firstname   4115 non-null   object
#  2   lastname    4031 non-null   object
#  3   petname     2894 non-null   object
#  4   dob         4115 non-null   object
#  5   sex         4115 non-null   int64
#  6   nationalid  0 non-null      float64
#  7   hdssid      4115 non-null   object
#  8   hdsshhid    4115 non-null   object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 289.5+ KB

# %%
household_data.isnull().sum()
# Out:
# recnr            0
# firstname        0
# lastname        84
# petname       1221
# dob              0
# sex              0
# nationalid    4115
# hdssid           0
# hdsshhid         0
# dtype: int64

# %%
print(household_data.firstname.value_counts().head(50))
# Out:
# Mutesi       73
# Naigaga      68
# Nabirye      62
# Nangobi      55
# Mariam       48
# Nakaziba     46
# Fatuma       33
# Babirye      31
# Hadija       29
# Kagoya       25
# Kaziba       25
# Kisambira    25
# Namususwa    23
# Sarah        22
# Naiwumbwe    22
# Florence     21
# Nakagolo     21
# Namukose     21
# Namuwaya     20
# Madina       20
# Nankwanga    20
# Janet        19
# Nakidodo     18
# Namaganda    18
# Zaituna      18
# Mukisa       17
# Amina        16
# John         15
# Betty        15
# Ruth         14
# Mwesigwa     14
# Sharon       14
# Aisa         14
# Shanita      14
# Rehema       14
# Tenywa       13
# Lukia        13
# Kaudha       13
# Zaina        13
# Hajira       13
# Hasifa       12
# Nasimu       12
# Zabina       12
# Aisha        12
# Namulondo    12
# Muwaya       12
# Namusobya    12
# Justine      12
# Lovisa       12
# Ayubu        12
# Name: firstname, dtype: int64

# %%
print(household_data.lastname.value_counts().head(50))
# Out:
# Naigaga      84
# Nabirye      80
# Nangobi      66
# Mutesi       60
# Nakaziba     50
# Nakagolo     45
# Babirye      42
# Namaganda    34
# Kagoya       29
# Naiwumbwe    29
# Namulondo    23
# Aisha        22
# Isabirye     21
# Fatuma       21
# Kauma        20
# Shanita      20
# Waiswa       19
# Namatende    19
# Nankwanga    19
# Nakiranda    18
# Kakaire      17
# Sowobi       16
# Namukose     16
# Sumaya       16
# Kaziba       16
# Kisambira    15
# Namumbya     14
# Namususwa    14
# Mukisa       14
# Sarah        14
# Lydia        14
# Tenywa       14
# Shakira      14
# Namuwaya     13
# Hadija       13
# Shamimu      13
# Nkwanga      12
# Namusubo     12
# Namwebya     12
# Madina       12
# Mariam       12
# Mutale       12
# Shamina      11
# Halima       11
# Naikoba      11
# Kaudha       11
# Nakisuyi     11
# Namwase      11
# Maganda      11
# Ngobi        11
# Name: lastname, dtype: int64

# %%
print(household_data.petname.value_counts().head(50))
# Out:
# Sira          26
# Ema           24
# Najjuma       23
# Lukwago       22
# Mugasha       21
# Masiko        21
# Vira          20
# Dara          20
# Yara          20
# Fara          19
# Tara          19
# Mira          19
# Mukitale      18
# Vara          18
# Masinde       18
# Lwanga        18
# Bria          18
# Mugenzi       18
# Chuma         17
# Uma           17
# Ula           16
# Mukama        16
# Mwesige       16
# Esa           15
# Pira          15
# Bisa          15
# Muhairwe      15
# Mukasa        15
# Nadduli       15
# Mukembo       15
# Qira          14
# Lubega        14
# Kyomuhendo    14
# Cira          14
# Lwasa         14
# Ora           14
# Masolo        14
# Magyezi       14
# Nira          14
# Dina          13
# Kyeyune       13
# Kira          13
# Zara          13
# Gani          13
# Femi          13
# Mukwaya       13
# Ima           13
# Wura          13
# Nakiwala      13
# Mwesigwa      13
# Name: petname, dtype: int64

# %%
print(household_data.dob.value_counts().head(50))
# Out:
# 09-08-1934 00:00    3
# 09-07-2016 00:00    3
# 14-01-1951 00:00    3
# 18-06-2020 00:00    3
# 03-12-2004 00:00    3
# 23-07-2023 00:00    2
# 18-08-2025 00:00    2
# 26-08-2014 00:00    2
# 28-03-2019 00:00    2
# 06-11-1977 00:00    2
# 28-12-1992 00:00    2
# 02-10-1950 00:00    2
# 11-08-1960 00:00    2
# 26-10-1983 00:00    2
# 05-09-1974 00:00    2
# 24-04-1960 00:00    2
# 24-10-2016 00:00    2
# 29-05-1994 00:00    2
# 15-05-2001 00:00    2
# 25-04-1984 00:00    2
# 17-06-1952 00:00    2
# 08-11-1986 00:00    2
# 17-01-1961 00:00    2
# 03-11-1991 00:00    2
# 27-12-2008 00:00    2
# 13-08-1999 00:00    2
# 12-06-1989 00:00    2
# 20-07-1930 00:00    2
# 02-10-2023 00:00    2
# 05-08-2022 00:00    2
# 15-03-1964 00:00    2
# 06-12-2007 00:00    2
# 01-01-1978 00:00    2
# 02-04-1981 00:00    2
# 04-10-1942 00:00    2
# 05-09-1980 00:00    2
# 27-12-1943 00:00    2
# 19-01-1998 00:00    2
# 24-10-1985 00:00    2
# 24-05-1959 00:00    2
# 03-03-2000 00:00    2
# ...

# %%
print(household_data['hdssid'].nunique())
# Out:
# 4115

# %%
print(household_data['hdsshhid'].nunique())
# Out:
# 4115
